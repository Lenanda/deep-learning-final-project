# %%
plt.figure(figsize=(6, 4))
sns.countplot(data=combined_data, x='dataset')
plt.title("Distribusi Jumlah Data: Train vs Test")
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(data=df_train, x='class', order=df_train['class'].value_counts().index)
plt.title("Distribusi Kelas pada Data Training")
plt.show()

# %%
df_train['text_length'] = df_train['tweets'].apply(lambda x: len(str(x).split()))
plt.figure(figsize=(8, 5))
sns.histplot(df_train['text_length'], bins=30, kde=True)
plt.title("Distribusi Panjang Teks (dalam kata)")
plt.xlabel("Jumlah Kata")
plt.ylabel("Frekuensi")
plt.show()

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='val')
plt.legend()
plt.title("Training vs Validation Loss")
plt.show()

# %% [markdown]
# Model klasifikasi tiga kelas yang diusulkan menghasilkan nilai macro F1-score sebesar 0.68 dan weighted F1-score sebesar 0.67. Hasil ini menunjukkan bahwa model mampu mengenali pola linguistik pada teks irony, sarcasm, dan regular secara seimbang, meskipun masih menghadapi tantangan dalam membedakan irony dan sarcasm yang memiliki kemiripan semantik tinggi.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_val, y_val_pred)

plt.imshow(cm, interpolation='nearest')
plt.title("Confusion Matrix")
plt.colorbar()
plt.xlabel("Predicted")
plt.ylabel("Actual")

tick_marks = range(len(le.classes_))
plt.xticks(tick_marks, le.classes_, rotation=45)
plt.yticks(tick_marks, le.classes_)

for i in range(len(cm)):
    for j in range(len(cm[0])):
        plt.text(j, i, cm[i, j], ha='center', va='center')

plt.show()
